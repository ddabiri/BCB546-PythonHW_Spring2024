# %%
ls
# Out:
# penguins_cytb.fasta  README.md              Untitled.ipynb
# penguins_mass.csv    sequence_translate.py

# %%
nano penguins_mass.csv
# Out:
#   Cell In[3], line 1
#     nano penguins_mass.csv
#          ^
# SyntaxError: invalid syntax

# %%
penguins_mass.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 penguins_mass.csv
#
# NameError: name 'penguins_mass' is not defined

# %%
R = penguins_mass.csv
print(R)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 R = penguins_mass.csv
#       2 print(R)
#
# NameError: name 'penguins_mass' is not defined
